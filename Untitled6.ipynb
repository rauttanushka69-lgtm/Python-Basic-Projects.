# %% [markdown]
# <a href="https://colab.research.google.com/github/rauttanushka69-lgtm/Python-Basic-Projects./blob/master/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Sample Countries data banavla
data = {
    'Country': ['India', 'USA', 'China', 'Brazil', 'Australia', 'Germany', 'Japan', 'Canada'],
    'Capital': ['Delhi', 'Washington D.C', 'Beijing', 'Brasilia', 'Canberra', 'Berlin', 'Tokyo', 'Ottawa'],
    'Continent': ['Asia', 'North America', 'Asia', 'South America', 'Australia', 'Europe', 'Asia', 'North America'],
    'Population': [1400000, 331000, 1440000, 213000, 25000000, 83000000, 125000, 38000000],
    'Area_km2': [3287263, 9833520, 9596961, 8515767, 7692024, 357114, 377975, 9984670]
}

df = pd.DataFrame(data)

# CSV file save kar
df.to_csv('Countries.csv', index=False)
print("✅ Countries.csv file banli")
# Out:
# ✅ Countries.csv file banli

# %%
import pandas as pd

# 1. File load kar
df = pd.read_csv("Countries.csv")

print("----- 1. HEAD - First 5 rows -----")
print(df.head())

print("\n----- 2. SHAPE - Rows and Columns -----")
print(df.shape)

print("\n----- 3. INFO -----")
df.info()

print("\n----- 4. DESCRIBE -----")
print(df.describe())

print("\n----- 5. COLUMNS -----")
print(df.columns)

print("\n----- 6. MISSING VALUES -----")
print(df.isnull().sum())

print("\n----- 7. DATA TYPES -----")
print(df.dtypes)
# Out:
# ----- 1. HEAD - First 5 rows -----
#      Country         Capital      Continent  Population  Area_km2
# 0      India           Delhi           Asia     1400000   3287263
# 1        USA  Washington D.C  North America      331000   9833520
# 2      China         Beijing           Asia     1440000   9596961
# 3     Brazil        Brasilia  South America      213000   8515767
# 4  Australia        Canberra      Australia    25000000   7692024
#
# ----- 2. SHAPE - Rows and Columns -----
# (8, 5)
#
# ----- 3. INFO -----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     8 non-null      object
#  1   Capital     8 non-null      object
#  2   Continent   8 non-null      object
#  3   Population  8 non-null      int64
#  4   Area_km2    8 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 452.0+ bytes
#
# ...
