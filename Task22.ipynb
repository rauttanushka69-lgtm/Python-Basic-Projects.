# %% [markdown]
# <a href="https://colab.research.google.com/github/rauttanushka69-lgtm/Python-Basic-Projects./blob/master/Task22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("heart.csv")

# Features and Target
X = df.drop("HeartDisease", axis=1)
y = df["HeartDisease"]

# Encode categorical columns
X = pd.get_dummies(X, drop_first=True)

print(X.head())
print(y.head())
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_M  \
# 0   40        140          289          0    172      0.0   True
# 1   49        160          180          0    156      1.0  False
# 2   37        130          283          0     98      0.0   True
# 3   48        138          214          0    108      1.5  False
# 4   54        150          195          0    122      0.0   True
#
#    ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  RestingECG_Normal  \
# 0               True              False             False               True
# 1              False               True             False               True
# 2               True              False             False              False
# 3              False              False             False               True
# 4              False               True             False               True
#
#    RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  ST_Slope_Up
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Scale data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.20,
    random_state=42
)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (734, 15)
# X_test shape: (184, 15)
# y_train shape: (734,)
# y_test shape: (184,)

# %%
from sklearn.linear_model import LogisticRegression

# Create Model
model = LogisticRegression()

# Train Model
model.fit(X_train, y_train)

print("Model Trained Successfully")
# Out:
# Model Trained Successfully

# %%
# Predict on test data
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix")
print(cm)

TN, FP, FN, TP = cm.ravel()

print("TN =", TN)
print("FP =", FP)
print("FN =", FN)
print("TP =", TP)
# Out:
# Confusion Matrix
# [[67 10]
#  [17 90]]
# TN = 67
# FP = 10
# FN = 17
# TP = 90

# %%
from sklearn.metrics import accuracy_score, precision_score
from sklearn.metrics import recall_score, f1_score
from sklearn.metrics import classification_report

print("Accuracy :", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall   :", recall_score(y_test, y_pred))
print("F1 Score :", f1_score(y_test, y_pred))

print("\nClassification Report")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy : 0.8532608695652174
# Precision: 0.9
# Recall   : 0.8411214953271028
# F1 Score : 0.8695652173913043
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83        77
#            1       0.90      0.84      0.87       107
#
#     accuracy                           0.85       184
#    macro avg       0.85      0.86      0.85       184
# weighted avg       0.86      0.85      0.85       184

# %%
import joblib

joblib.dump(model, "heart_model.pkl")
joblib.dump(scaler, "scaler.pkl")
joblib.dump(X.columns.tolist(), "columns.pkl")

print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
import joblib
import pandas as pd

# Load saved files
model = joblib.load("heart_model.pkl")
scaler = joblib.load("scaler.pkl")
columns = joblib.load("columns.pkl")

# Sample Input
sample = {
    "Age": 65,
    "RestingBP": 120,
    "Cholesterol": 220,
    "FastingBS": 0,
    "MaxHR": 150,
    "Oldpeak": 1.0
}

sample_df = pd.DataFrame([sample])

# Match columns
sample_df = sample_df.reindex(columns=columns, fill_value=0)

# Scale
sample_scaled = scaler.transform(sample_df)

# Prediction
prediction = model.predict(sample_scaled)

print("Prediction:", prediction[0])

if prediction[0] == 1:
    print("Heart Disease: Yes")
else:
    print("Heart Disease: No")
# Out:
# Prediction: 0
# Heart Disease: No

# %%
import streamlit as st

st.title("Heart Disease Prediction")

age = st.number_input("Age", 1, 100)
bp = st.number_input("Resting BP", 50, 250)
chol = st.number_input("Cholesterol", 50, 600)
fbs = st.selectbox("Fasting Blood Sugar", [0, 1])
maxhr = st.number_input("Max Heart Rate", 50, 250)
oldpeak = st.number_input("Old Peak", 0.0, 10.0)

if st.button("Predict"):
    st.write("Prediction Button Clicked")
# Out:
# 2026-07-20 09:58:50.004 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-20 09:58:50.632
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-07-20 09:58:50.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-20 09:58:50.638 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-20 09:58:50.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-20 09:58:50.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-20 09:58:50.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
# !pip install -q streamlit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 45.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 57.0 MB/s eta 0:00:00

# %%
import streamlit as st
print("Streamlit installed successfully!")
# Out:
# Streamlit installed successfully!

# %%
# %%writefile app.py
import streamlit as st

st.title("Heart Disease Prediction")

age = st.number_input("Age", 1, 100)
bp = st.number_input("Resting BP", 50, 250)
chol = st.number_input("Cholesterol", 50, 600)
fbs = st.selectbox("Fasting Blood Sugar", [0, 1])
maxhr = st.number_input("Max Heart Rate", 50, 250)
oldpeak = st.number_input("Old Peak", 0.0, 10.0)

if st.button("Predict"):
    st.success("Prediction Button Clicked")
# Out:
# Writing app.py

# %%
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹
# changed 22 packages in 2s
# ⠹
# ⠹3 packages are looking for funding
# ⠹  run `npm fund` for details
# ⠹

# %%
# !streamlit run app.py &>/content/log.txt &

# %%
# !lt --port 8501
# Out:
# your url is: https://good-cougars-fix.loca.lt
